# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def Plotvec2(a, b):
    ax = plt.axes()
    ax.arrow(0, 0, *a, head_width=0.05, color='r', head_length=0.1)
    plt.text(*(a + 0.1), 'a')
    ax.arrow(0, 0, *b, head_width=0.05, color='b', head_length=0.1)
    plt.text(*(b + 0.1), 'b')
    plt.ylim(-2, 2)
    plt.xlim(-2, 2)
    plt.grid()
    plt.show()

# %%
u = np.array([1, 0])
v = np.array([0, 1])

u - v
# Out:
# array([ 1, -1])

# %%
z = np.array([2, 4])

-2 * z
# Out:
# array([-4, -8])

# %%
a = np.array([1, 2, 3, 4, 5])
b = np.array([1, 0, 1, 0, 1])

a * b
# Out:
# array([1, 0, 3, 0, 5])

# %%
a = np.array([-1, 1])
b = np.array([1, 1])

Plotvec2(a, b)
print("The dot product is", np.dot(a, b))
# Out:
# The dot product is 0

# %%
a = np.array([1, 0])
b = np.array([0, 1])

Plotvec2(a, b)
print("The dot product is", np.dot(a, b))
# Out:
# The dot product is 0

# %%
a = np.array([1, 1])
b = np.array([0, 1])

Plotvec2(a, b)
print("The dot product is", np.dot(a, b))
# Out:
# The dot product is 1

# %%
print("The vectors in questions 4 and 5 are perpendicular, so their dot product is zero. The vectors in question 6 are not perpendicular, so the dot product is not zero.")
# Out:
# The vectors in questions 4 and 5 are perpendicular, so their dot product is zero. The vectors in question 6 are not perpendicular, so the dot product is not zero.

# %%
arr1 = np.array([1, 2, 3])
arr2 = np.array([8, 9, 10])

print("Addition:", np.add(arr1, arr2))
print("Subtraction:", np.subtract(arr1, arr2))
print("Multiplication:", np.multiply(arr1, arr2))
print("Division:", np.divide(arr1, arr2))
print("Dot Product:", np.dot(arr1, arr2))
# Out:
# Addition: [ 9 11 13]
# Subtraction: [-7 -7 -7]
# Multiplication: [ 8 18 30]
# Division: [0.125      0.22222222 0.3       ]
# Dot Product: 56

# %%
arr1 = np.array([1, 2, 3, 4, 5])
arr2 = np.array([6, 7, 8, 9, 10])

even_arr1 = arr1[1:5:2]
print("even for array1", even_arr1)

odd_arr1 = arr1[0:5:2]
print("odd for array1", odd_arr1)

even_arr2 = arr2[0:5:2]
print("even for array2", even_arr2)

odd_arr2 = arr2[1:5:2]
print("odd for array2", odd_arr2)
# Out:
# even for array1 [2 4]
# odd for array1 [1 3 5]
# even for array2 [ 6  8 10]
# odd for array2 [7 9]
